# %%
import requests
import bs4
res = requests.get("https://data.oecd.org/inequality/violence-against-women.htm#indicator-chart")
soup = bs4.BeautifulSoup(res.text, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Inequality - Violence against women - OECD Data</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/>
# <meta content="always" name="referrer"/>
# <meta content="The violence against women indicator presents you with data on attitudes towards violence, prevalence of violence as well as data on the law about violence." name="description"/>
# <meta content="violence; domestic; rape; sex; harassment; law; right; inequality; gini; index; income; wealth; gender" name="keywords"/>
# <script type="text/javascript">
#   var languageSwitch = '<a href="">âº </a><a href="/fr/inequality/violences-faites-aux-femmes.htm">Fran&ccedil;ais</a><!--<a href="/inequality/violence-against-women.htm">English</a>-->';
# </script>
# <script>
# dataLayer = [{
# 	'siteName':"data",
# 	'siteEnvironment':"live",
# ...
